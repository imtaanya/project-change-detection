# %% [markdown]
# #Install libraries

# %%
import sys
print(sys.executable)
# Out:
# C:\ProgramData\anaconda3\python.exe

# %%
# !{sys.executable} -m pip install sentinelsat geopandas shapely tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from sentinelsat import SentinelAPI
print(" Sentinelsat imported successfully!")
# Out:
#  Sentinelsat imported successfully!

# %%
import requests
from requests.auth import HTTPBasicAuth

USERNAME = "ravik2.paschim@gmail.com"
PASSWORD = "XHM0UExR>W36"

query_url = (
    "https://scihub.copernicus.eu/dhus/search?"
    "format=json&q=platformname:Sentinel-1 AND producttype:GRD "
    "AND beginPosition:[2025-07-01T00:00:00.000Z TO 2025-09-02T00:00:00.000Z]"
)

response = requests.get(query_url, auth=HTTPBasicAuth(USERNAME, PASSWORD))
response.raise_for_status()

data = response.json()
print(data)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File C:\ProgramData\anaconda3\Lib\site-packages\urllib3\util\connection.py:73, in create_connection(address, timeout, source_address, socket_options)
# ...
