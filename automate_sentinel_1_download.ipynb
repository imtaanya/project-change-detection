# %%
pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopandas>=0.14 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: shapely>=2.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 5)) (2.1.2)
# Requirement already satisfied: rasterio>=1.3 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 6)) (1.4.3)
# Requirement already satisfied: numpy>=1.26 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 7)) (2.1.3)
# Requirement already satisfied: matplotlib>=3.9 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 8)) (3.10.0)
# Requirement already satisfied: tqdm>=4.66 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: scikit-image>=0.24 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 10)) (0.25.0)
# Requirement already satisfied: scikit-learn>=1.5 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 11)) (1.6.1)
# Requirement already satisfied: opencv-python>=4.10 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 12)) (4.12.0.88)
# Requirement already satisfied: scipy>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 16)) (1.15.3)
# Requirement already satisfied: sentinelsat>=1.2.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 20)) (1.2.1)
# Requirement already satisfied: requests>=2.31.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 21)) (2.32.3)
# Requirement already satisfied: pyyaml>=6.0 in c:\programdata\anaconda3\lib\site-packages (from -r requirements.txt (line 24)) (6.0.2)
# Requirement already satisfied: pathlib2>=2.3.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 25)) (2.3.7.post1)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from geopandas>=0.14->-r requirements.txt (line 4)) (0.11.1)
# Requirement already satisfied: packaging in c:\programdata\anaconda3\lib\site-packages (from geopandas>=0.14->-r requirements.txt (line 4)) (24.2)
# Requirement already satisfied: pandas>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from geopandas>=0.14->-r requirements.txt (line 4)) (2.2.3)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\admin\appdata\roaming\python\python313\site-packages (from geopandas>=0.14->-r requirements.txt (line 4)) (3.7.2)
# Requirement already satisfied: affine in c:\users\admin\appdata\roaming\python\python313\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (2.4.0)
# Requirement already satisfied: attrs in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (24.3.0)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (2025.7.14)
# Requirement already satisfied: click>=4.0 in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in c:\users\admin\appdata\roaming\python\python313\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (0.7.2)
# Requirement already satisfied: click-plugins in c:\users\admin\appdata\roaming\python\python313\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (1.1.1.2)
# Requirement already satisfied: pyparsing in c:\programdata\anaconda3\lib\site-packages (from rasterio>=1.3->-r requirements.txt (line 6)) (3.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (11.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\programdata\anaconda3\lib\site-packages (from matplotlib>=3.9->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.66->-r requirements.txt (line 9)) (0.4.6)
# Requirement already satisfied: networkx>=3.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.24->-r requirements.txt (line 10)) (3.4.2)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.24->-r requirements.txt (line 10)) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.24->-r requirements.txt (line 10)) (2025.2.18)
# Requirement already satisfied: lazy-loader>=0.4 in c:\programdata\anaconda3\lib\site-packages (from scikit-image>=0.24->-r requirements.txt (line 10)) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.5->-r requirements.txt (line 11)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn>=1.5->-r requirements.txt (line 11)) (3.5.0)
# Requirement already satisfied: html2text in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentinelsat>=1.2.0->-r requirements.txt (line 20)) (2025.4.15)
# Requirement already satisfied: geojson>=2 in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentinelsat>=1.2.0->-r requirements.txt (line 20)) (3.2.0)
# Requirement already satisfied: geomet in c:\users\admin\appdata\roaming\python\python313\site-packages (from sentinelsat>=1.2.0->-r requirements.txt (line 20)) (1.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 21)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 21)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.31.0->-r requirements.txt (line 21)) (2.3.0)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from pathlib2>=2.3.0->-r requirements.txt (line 25)) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas>=0.14->-r requirements.txt (line 4)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas>=2.0.0->geopandas>=0.14->-r requirements.txt (line 4)) (2025.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Import and Authenticate

# %%
from sentinelsat import SentinelAPI, read_geojson, geojson_to_wkt
from datetime import datetime
import os
import json

# --- User parameters ---
# Create a folder for data
DATA_DIR = "sentinel_downloads"
os.makedirs(DATA_DIR, exist_ok=True)

# Your Copernicus Data Space credentials
CATALOGUE_URL = "https://catalogue.dataspace.copernicus.eu/odata/v1/Products"
USER = "ravik2.paschim@gmail.com"  # <-- put your Copernicus Data Space username
PASSWORD = "XHM0UExR>W36"  # <-- put your password

# Connect to the new Copernicus Data Space API
api = SentinelAPI(USER, PASSWORD, "https://catalogue.dataspace.copernicus.eu/apihub")

print(" Connected to Copernicus Data Space successfully!")
# Out:
#  Connected to Copernicus Data Space successfully!

# %%
# Load credentials, AOI path, and time range from config.yaml
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

USERNAME = config["username"]
PASSWORD = config["password"]
AOI_PATH = config["aoi_path"]
START_DATE = config["start_date"]
END_DATE = config["end_date"]

print("Configuration file loaded successfully.")
# Out:
# Configuration file loaded successfully.

# %%
import yaml
from urllib.parse import quote

# ===================== LOAD CONFIGURATION =====================
with open("config.yaml", "r") as f:
    config = yaml.safe_load(f)

USERNAME = config["username"]
PASSWORD = config["password"]
AOI_PATH = config["aoi_path"]
START_DATE = config["start_date"]
END_DATE = config["end_date"]

# ===================== AUTHENTICATION =====================
print("Authenticating...")
token_url = "https://identity.dataspace.copernicus.eu/auth/realms/CDSE/protocol/openid-connect/token"
data = {
    "client_id": "cdse-public",
    "grant_type": "password",
    "username": USERNAME,
    "password": PASSWORD,
}
resp = requests.post(token_url, data=data)
resp.raise_for_status()
access_token = resp.json()["access_token"]
headers = {"Authorization": f"Bearer {access_token}"}
print("Auth success!")

# ===================== LOAD AOI GEOJSON =====================
aoi = gpd.read_file(AOI_PATH)
geom = aoi.geometry.iloc[0]
try:
    polygon_wkt = geom.to_wkt()
except AttributeError:
    polygon_wkt = geom.wkt
print("AOI loaded successfully!")

# Encode polygon for URL safety (avoid 400 Bad Request)
polygon_encoded = quote(polygon_wkt)

# ===================== QUERY SENTINEL-1 PRODUCTS =====================
query_url = (
    "https://catalogue.dataspace.copernicus.eu/odata/v1/Products?"
    "$filter="
    f"OData.CSC.Intersects(area=geography'SRID=4326;{polygon_encoded}') "
    "and Collection/Name eq 'SENTINEL-1' "
    f"and ContentDate/Start gt {START_DATE} "
    f"and ContentDate/Start lt {END_DATE}"
    "&$orderby=ContentDate/Start desc"
    "&$top=20"
)

print("Sending query to Copernicus Data Space...")
resp = requests.get(query_url, headers=headers)
resp.raise_for_status()

# ===================== PROCESS RESULTS =====================
results = resp.json().get("value", [])
print(f"Found {len(results)} Sentinel-1 products\n")

for r in results:
    print(f"{r['Name']} — {r['ContentDate']['Start']}")
# Out:
# Authenticating...
# Auth success!
# AOI loaded successfully!
# Sending query to Copernicus Data Space...
# Found 20 Sentinel-1 products
#
# S1A_IW_GRDH_1SDV_20250923T005158_20250923T005223_061108_079DF5_7688_COG.SAFE — 2025-09-23T00:51:58.781428Z
# S1A_IW_GRDH_1SDV_20250923T005158_20250923T005223_061108_079DF5_250B.SAFE — 2025-09-23T00:51:58.781428Z
# S1A_IW_SLC__1SDV_20250923T005158_20250923T005225_061108_079DF5_9C00.SAFE — 2025-09-23T00:51:58.181472Z
# S1A_IW_ETA__AXDV_20250923T005158_20250923T005225_061108_079DF5_6E41.SAFE — 2025-09-23T00:51:58.123167Z
# S1A_IW_RAW__0SDV_20250923T005155_20250923T005227_061108_079DF5_6251.SAFE — 2025-09-23T00:51:55.081627Z
# S1A_IW_RAW__0SDV_20250923T005130_20250923T005202_061108_079DF5_F416.SAFE — 2025-09-23T00:51:30.081261Z
# S1A_IW_GRDH_1SDV_20250922T124755_20250922T124820_061101_079DB9_1A15_COG.SAFE — 2025-09-22T12:47:55.368644Z
# S1A_IW_GRDH_1SDV_20250922T124755_20250922T124820_061101_079DB9_6113.SAFE — 2025-09-22T12:47:55.368644Z
# S1A_IW_SLC__1SDV_20250922T124754_20250922T124821_061101_079DB9_FEF6.SAFE — 2025-09-22T12:47:54.504722Z
# S1A_IW_ETA__AXDV_20250922T124754_20250922T124821_061101_079DB9_0EFC.SAFE — 2025-09-22T12:47:54.457478Z
# S1A_IW_RAW__0SDV_20250922T124751_20250922T124824_061101_079DB9_1406.SAFE — 2025-09-22T12:47:51.667915Z
# S1A_IW_GRDH_1SDV_20250922T124730_20250922T124755_061101_079DB9_05C1.SAFE — 2025-09-22T12:47:30.368372Z
# S1A_IW_GRDH_1SDV_20250922T124730_20250922T124755_061101_079DB9_06C8_COG.SAFE — 2025-09-22T12:47:30.368372Z
# S1A_IW_SLC__1SDV_20250922T124729_20250922T124756_061101_079DB9_B133.SAFE — 2025-09-22T12:47:29.681824Z
# S1A_IW_ETA__AXDV_20250922T124729_20250922T124756_061101_079DB9_46AE.SAFE — 2025-09-22T12:47:29.648094Z
# S1A_IW_RAW__0SDV_20250922T124726_20250922T124759_061101_079DB9_0362.SAFE — 2025-09-22T12:47:26.667839Z
# S1A_IW_GRDH_1SDV_20250918T004352_20250918T004417_061035_079B11_FD56.SAFE — 2025-09-18T00:43:52.415578Z
# S1A_IW_GRDH_1SDV_20250918T004352_20250918T004417_061035_079B11_F39D_COG.SAFE — 2025-09-18T00:43:52.415578Z
# S1A_IW_SLC__1SDV_20250918T004351_20250918T004418_061035_079B11_91AF.SAFE — 2025-09-18T00:43:51.812035Z
# S1A_IW_ETA__AXDV_20250918T004351_20250918T004418_061035_079B11_A673.SAFE — 2025-09-18T00:43:51.759531Z

# %%
# Filter only Interferometric Wide Ground Range Detected (IW_GRDH) products
grdh_products = [p for p in results if "IW_GRDH" in p["Name"]]

print(f"\nFound {len(grdh_products)} IW_GRDH products.\n")

if not grdh_products:
    print("No IW_GRDH products found for this AOI and date range.")
else:
    for i, r in enumerate(grdh_products, start=1):
        print(f"{i}. {r['Name']} — {r['ContentDate']['Start']}")
# Out:
# Found 8 IW_GRDH products.
#
# 1. S1A_IW_GRDH_1SDV_20250923T005158_20250923T005223_061108_079DF5_7688_COG.SAFE — 2025-09-23T00:51:58.781428Z
# 2. S1A_IW_GRDH_1SDV_20250923T005158_20250923T005223_061108_079DF5_250B.SAFE — 2025-09-23T00:51:58.781428Z
# 3. S1A_IW_GRDH_1SDV_20250922T124755_20250922T124820_061101_079DB9_1A15_COG.SAFE — 2025-09-22T12:47:55.368644Z
# 4. S1A_IW_GRDH_1SDV_20250922T124755_20250922T124820_061101_079DB9_6113.SAFE — 2025-09-22T12:47:55.368644Z
# 5. S1A_IW_GRDH_1SDV_20250922T124730_20250922T124755_061101_079DB9_05C1.SAFE — 2025-09-22T12:47:30.368372Z
# 6. S1A_IW_GRDH_1SDV_20250922T124730_20250922T124755_061101_079DB9_06C8_COG.SAFE — 2025-09-22T12:47:30.368372Z
# 7. S1A_IW_GRDH_1SDV_20250918T004352_20250918T004417_061035_079B11_FD56.SAFE — 2025-09-18T00:43:52.415578Z
# 8. S1A_IW_GRDH_1SDV_20250918T004352_20250918T004417_061035_079B11_F39D_COG.SAFE — 2025-09-18T00:43:52.415578Z

# %%
# Allow the user to select a product and download it
if grdh_products:
    try:
        choice = int(input("\nEnter the number of the product you want to download: ").strip())
        if 1 <= choice <= len(grdh_products):
            selected = grdh_products[choice - 1]
            product_id = selected["Id"]

            # Construct the direct download URL
            download_url = f"https://zipper.dataspace.copernicus.eu/odata/v1/Products({product_id})/$value"
            print(f"\nDownload URL:\n{download_url}\n")

            confirm = input("Do you want to download this file? (y/n): ").lower()
            if confirm == "y":
                filename = f"{selected['Name']}.zip"
                print(f"Downloading {filename}...")

                with requests.get(download_url, headers=headers, stream=True) as file_resp:
                    file_resp.raise_for_status()
                    with open(filename, "wb") as f:
                        for chunk in file_resp.iter_content(chunk_size=8192):
                            f.write(chunk)

                print(f"Download complete: {filename}")
            else:
                print("Download cancelled.")
        else:
            print("Invalid selection.")
    except ValueError:
        print("Please enter a valid number.")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 4
#       2 if grdh_products:
#       3     try:
# ----> 4         choice = int(input("\nEnter the number of the product you want to download: ").strip())
#       5         if 1 <= choice <= len(grdh_products):
#       6             selected = grdh_products[choice - 1]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
